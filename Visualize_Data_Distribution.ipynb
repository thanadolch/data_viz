# %% [markdown]
# <a href="https://colab.research.google.com/github/thanadolch/data_viz/blob/main/Visualize_Data_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #การแสดงผลที่ดูการกระจายของข้อมูล
# ### Scatter
# ### Scatter 3D

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# scatter-defualt

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'])

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
df2 = df.replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c=df2['Name'])

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c=df2['Name'],alpha=0.5)

# %% [markdown]
# ##ใช้ขนาดของ marker แสดงค่าของ feature

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],s=20*df['SepalWidth'],c=df2['Name'],alpha=0.5)

# %% [markdown]
# ##ตัวแปร Marker ใช้ในการเปลี่ยนหน้าตาของ marker

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],s=20*df['SepalWidth'],c=df2['Name'],alpha=0.5,marker='x')

# %% [markdown]
# ##การ plot กราฟหลายๆอันซ้อนกัน

# %%
plt.scatter(df['PetalLength'][:50],df['PetalWidth'][:50],s=100,c='m',alpha=0.5,marker='$a$')
plt.scatter(df['PetalLength'][50:100],df['PetalWidth'][50:100],s=100,c='c',alpha=0.5,marker='$b$')
plt.scatter(df['PetalLength'][100:],df['PetalWidth'][100:],s=100,c='r',alpha=0.5,marker='$c$')

# %% [markdown]
# #Label-Legend

# %% [markdown]
# ```plt.plot()```input ตัวที่3 คือ ตัวกำหนดหน้าตาของ marker
# 'หน้าตา marker'-'ลักษณะของเส้นเชื่อมจุด'-'สี'

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'o-r',alpha=0.5)

# %%
plt.plot(df['PetalLength'][50:100],df['PetalWidth'][50:100],'o:r',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5,label='setosa')
plt.plot(df['PetalLength'][50:100],df['PetalWidth'][50:100],'xc',alpha=0.5,label='versicolor')
plt.plot(df['PetalLength'][100:],df['PetalWidth'][100:],'*m',alpha=0.5,label='verginica')
plt.legend()
plt.title('Iris flower data distribution')
plt.xlabel('PetalLength')
plt.ylabel('PetalWidth');

# %%
ax = plt.axes(projection ="3d")
ax.scatter3D(df['PetalLength'],df['PetalWidth'],df['SepalWidth'],c=df2['Name'])

# %% [markdown]
# ### Bubble Chart

# %%
plt.scatter(df['PetalLength'][:50],df['PetalWidth'][:50],s=200*df['SepalWidth'][:50],c='r')

# %% [markdown]
# #Example

# %%
import os

# %%
path = '/content/drive/My Drive/DVZ'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_excel(os.path.join(path,'passenger-covid19.xlsx'),sheet_name=1)
data = data.dropna()
data.head()
# Out:
#   ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-13 00:00:00 2021-03-14 00:00:00
# 0     ขนคน (คน)          ทางบก  ...             51204.0             58371.0
# 3    ขนคน (คัน)          ทางบก  ...            940739.0            870772.0
# 4    ขนคน (คัน)          ทางบก  ...           1348121.0           1211478.0
# 5    ขนคน (คัน)          ทางบก  ...           1305116.0           1192083.0
# 6    ขนคน (คัน)          ทางบก  ...           1090319.0           1045273.0
#
# [5 rows x 445 columns]

# %%
from datetime import datetime
data.columns = [i.strftime('%Y-%m-%d') if isinstance(i,datetime) else i for i in data.columns]
data.head()
# Out:
#   ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-13 2021-03-14
# 0     ขนคน (คน)          ทางบก  ...    51204.0    58371.0
# 3    ขนคน (คัน)          ทางบก  ...   940739.0   870772.0
# 4    ขนคน (คัน)          ทางบก  ...  1348121.0  1211478.0
# 5    ขนคน (คัน)          ทางบก  ...  1305116.0  1192083.0
# 6    ขนคน (คัน)          ทางบก  ...  1090319.0  1045273.0
#
# [5 rows x 445 columns]

# %%
all = set(list(data['ยานพาหนะ/ท่า']))
all_g = list(all)
all_g.sort()
color_list2 = {}
num = 0
for each_g in all_g:
    if each_g not in color_list2:
        color_list2[each_g] = num
        num +=1

# %%
color_list2
# Out:
# {'ท่าอากาศยานดอนเมือง': 0,
#  'ท่าอากาศยานดอนเมือง ขาออกประเทศ': 1,
#  'ท่าอากาศยานดอนเมือง ขาเข้าประเทศ': 2,
#  'ท่าอากาศยานภูมิภาค': 3,
#  'ท่าอากาศยานภูมิภาค ขาออกประเทศ': 4,
#  'ท่าอากาศยานภูมิภาค ขาเข้าประเทศ': 5,
#  'ท่าอากาศยานสุวรรณภูมิ': 6,
#  'ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ': 7,
#  'ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ': 8,
#  'ท่าอากาศอื่น ๆ ของ ทอท.': 9,
#  'ท่าอากาศอื่น ๆ ของ ทอท. ขาออกประเทศ': 10,
#  'ท่าอากาศอื่น ๆ ของ ทอท.ขาเข้าประเทศ': 11,
#  'รถ ขบส. และ รถร่วม': 12,
#  'รถยนต์ทุกประเภท (10 จุดสำรวจ)': 13,
#  'รถยนต์ทุกประเภท (ทางด่วน)': 14,
#  'รถยนต์เฉพาะ 4 ล้อ (10 จุดสำรวจ)': 15,
#  'รถยนต์เฉพาะ 4 ล้อ (ทางด่วน)': 16,
#  'รถร่วม (หมวด 1)': 17,
#  'รถเมล์ ขสมก.': 18,
#  'รถไฟ': 19,
#  'รถไฟฟ้า ARL': 20,
#  'รถไฟฟ้า BTS': 21,
#  'รถไฟฟ้าสายสีน้ำเงิน': 22,
#  'รถไฟฟ้าสายสีม่วง': 23,
#  'เรือคลองแสนแสบ': 24,
#  'เรือภูมิภาค': 25,
#  'เรือเจ้าพระยา': 26}

# %%
data['Car'] = data['ยานพาหนะ/ท่า'].map({'ท่าอากาศยานดอนเมือง':1,'ท่าอากาศยานดอนเมือง ขาออกประเทศ':2,'ท่าอากาศยานดอนเมือง ขาเข้าประเทศ':3,'ท่าอากาศยานภูมิภาค':4,'ท่าอากาศยานภูมิภาค ขาออกประเทศ':5,'ท่าอากาศยานภูมิภาค ขาเข้าประเทศ':6,'ท่าอากาศยานสุวรรณภูมิ':7,'ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ':8,'ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ':9,'ท่าอากาศอื่น ๆ ของ ทอท.':10,'ท่าอากาศอื่น ๆ ของ ทอท. ขาออกประเทศ':11,'ท่าอากาศอื่น ๆ ของ ทอท.ขาเข้าประเทศ':12,'รถ ขบส. และ รถร่วม':13,'รถยนต์ทุกประเภท (10 จุดสำรวจ)':14,'รถยนต์ทุกประเภท (ทางด่วน)':15,'รถยนต์เฉพาะ 4 ล้อ (10 จุดสำรวจ)':16,'รถยนต์เฉพาะ 4 ล้อ (ทางด่วน)':17,'รถร่วม (หมวด 1)':18,'รถเมล์ ขสมก.':19,'รถไฟ':20,'รถไฟฟ้า ARL':21,'รถไฟฟ้า BTS':22,'รถไฟฟ้าสายสีน้ำเงิน':23,'รถไฟฟ้าสายสีม่วง':24,'เรือคลองแสนแสบ':25,'เรือภูมิภาค':26,'เรือเจ้าพระยา':27})
data.head()
# Out:
#   ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-14 Car
# 0     ขนคน (คน)          ทางบก  ...    58371.0  13
# 3    ขนคน (คัน)          ทางบก  ...   870772.0  16
# 4    ขนคน (คัน)          ทางบก  ...  1211478.0  14
# 5    ขนคน (คัน)          ทางบก  ...  1192083.0  17
# 6    ขนคน (คัน)          ทางบก  ...  1045273.0  15
#
# [5 rows x 446 columns]

# %%
daat = data.sort_values('Car')
daat.head()
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-14 Car
# 26     ขนคน (คน)       ทางอากาศ  ...    14751.0   1
# 38     ขนคน (คน)       ทางอากาศ  ...        1.0   2
# 37     ขนคน (คน)       ทางอากาศ  ...        0.0   3
# 28     ขนคน (คน)       ทางอากาศ  ...    15154.0   4
# 42     ขนคน (คน)       ทางอากาศ  ...        0.0   5
#
# [5 rows x 446 columns]

# %%
plt.scatter(daat['Car'],daat['2020-01-01'],s=0.004*daat['2020-01-04'],c='r',alpha=0.5)
plt.title('Traveling')
plt.xlabel('Vehicle')
plt.ylabel('Number person in 2020-01-04');

# %%
plt.scatter(daat['Car'][10:25],daat['2020-01-01'][10:25],s=0.004*daat['2020-01-04'][10:25],c='b',alpha=0.5)
plt.title('Traveling')
plt.xlabel('Vehicle')
plt.ylabel('Number person in 2020-01-04');

# %%
 def traveling(put,value):
      plt.scatter(daat['Car'],daat[put],s=0.004*daat[value],c='r',alpha=0.5)
      plt.title('Traveling')
      plt.xlabel('Vehicle')
      plt.ylabel('Number person in 2020-01-04');

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
p = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True)
p
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fb656073c50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb656079d10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb6560092d0>],
#  'means': [<matplotlib.lines.Line2D at 0x7fb656080d50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb656080810>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fb656079290>,
#   <matplotlib.lines.Line2D at 0x7fb6560797d0>]}

# %%
p['fliers'][0].get_ydata()
# Out:
# array([2. , 4.4, 4.1, 4.2])

# %%
v = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True,vert=False)
